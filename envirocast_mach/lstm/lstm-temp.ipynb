# %% [markdown]
# # LSTM - Temp

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/data_imputed_2.csv")

# %%
df.head()
# Out:
#    timestamp_local  temp city_name country_code  aqi      co   no2    o3  \
# 0  01/02/2022 0:00  12.6    Gujrāt           PK  385  1339.8  76.0  10.7
# 1  01/02/2022 1:00  11.5    Gujrāt           PK  404  1437.6  76.0   9.3
# 2  01/02/2022 2:00  11.9    Gujrāt           PK  421  1535.5  76.0   8.0
# 3  01/02/2022 3:00  12.2    Gujrāt           PK  425  1659.0  68.3   5.3
# 4  01/02/2022 4:00  11.9    Gujrāt           PK  430  1782.5  60.7   2.7
#
#     pm10    pm25    so2
# 0  491.7  347.67  238.0
# 1  508.3  359.33  268.0
# 2  525.0  371.00  298.0
# 3  529.3  374.00  275.7
# 4  533.7  377.00  253.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19706 entries, 0 to 19705
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp_local  19706 non-null  object
#  1   temp             19706 non-null  float64
#  2   city_name        19706 non-null  object
#  3   country_code     19706 non-null  object
#  4   aqi              19706 non-null  int64
#  5   co               19706 non-null  float64
#  6   no2              19706 non-null  float64
#  7   o3               19706 non-null  float64
#  8   pm10             19706 non-null  float64
#  9   pm25             19706 non-null  float64
#  10  so2              19706 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 1.7+ MB

# %%
data = df[['temp']]

# %% [markdown]
# ## Data PreProcessing

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
dataset = data
values = dataset.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
def series_to_supervised(data, n_in = 1, n_out = 1, dropnan = True):
    n_vars = 1 if type(data) is list else data.shape[1]
    
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
        
    return agg

# %%
# converting the dataset as supervised learning
reframed = series_to_supervised(scaled, 168, 1)
print(reframed.shape)
# Out:
# (19538, 169)

# %%
reframed.head()
# Out:
#      var1(t-168)  var1(t-167)  var1(t-166)  var1(t-165)  var1(t-164)  \
# 168     0.221709     0.196305     0.205543     0.212471     0.205543
# 169     0.196305     0.205543     0.212471     0.205543     0.196305
# 170     0.205543     0.212471     0.205543     0.196305     0.170901
# 171     0.212471     0.205543     0.196305     0.170901     0.152425
# 172     0.205543     0.196305     0.170901     0.152425     0.170901
#
#      var1(t-163)  var1(t-162)  var1(t-161)  var1(t-160)  var1(t-159)  ...  \
# 168     0.196305     0.170901     0.152425     0.170901     0.187067  ...
# 169     0.170901     0.152425     0.170901     0.187067     0.290993  ...
# 170     0.152425     0.170901     0.187067     0.290993     0.323326  ...
# 171     0.170901     0.187067     0.290993     0.323326     0.348730  ...
# 172     0.187067     0.290993     0.323326     0.348730     0.401848  ...
#
#      var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  \
# 168   0.418014   0.427252   0.418014   0.418014   0.307159   0.272517
# 169   0.427252   0.418014   0.418014   0.307159   0.272517   0.272517
# 170   0.418014   0.418014   0.307159   0.272517   0.272517   0.247113
# 171   0.418014   0.307159   0.272517   0.272517   0.247113   0.237875
# 172   0.307159   0.272517   0.272517   0.247113   0.237875   0.221709
#
#      var1(t-3)  var1(t-2)  var1(t-1)   var1(t)
# 168   0.272517   0.247113   0.237875  0.221709
# 169   0.247113   0.237875   0.221709  0.205543
# 170   0.237875   0.221709   0.205543  0.196305
# 171   0.221709   0.205543   0.196305  0.177829
# 172   0.205543   0.196305   0.177829  0.170901
#
# [5 rows x 169 columns]

# %%
reframed.columns
# Out:
# Index(['var1(t-168)', 'var1(t-167)', 'var1(t-166)', 'var1(t-165)',
#        'var1(t-164)', 'var1(t-163)', 'var1(t-162)', 'var1(t-161)',
#        'var1(t-160)', 'var1(t-159)',
#        ...
#        'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)', 'var1(t-5)',
#        'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)', 'var1(t)'],
#       dtype='object', length=169)

# %%
values = reframed.values

# We train the model on the 1st 1 and a half years of data and then test on the remaining 
n_train_hours = int(365 * 24 * 1.5)

train = values[:n_train_hours, :]
test = values[n_train_hours:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D :- (no.of samples, no.of timesteps, no.of features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (13140, 1, 168) (13140,) (6398, 1, 168) (6398,)

# %%
train.shape, test.shape, values.shape
# Out:
# ((13140, 169), (6398, 169), (19538, 169))

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# ### Model 1

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
import matplotlib.pyplot as plt

# %%
model = Sequential()
model.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(64))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          59,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 59,713 (233.25 KB)
#  Trainable params: 59,713 (233.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_split=0.2, verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 146/146 - 2s - 14ms/step - loss: 0.0062 - val_loss: 0.0039
# Epoch 2/50
# 146/146 - 1s - 7ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 3/50
# 146/146 - 1s - 5ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 4/50
# 146/146 - 1s - 4ms/step - loss: 0.0028 - val_loss: 0.0036
# Epoch 5/50
# 146/146 - 0s - 2ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 6/50
# 146/146 - 0s - 2ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 7/50
# 146/146 - 0s - 2ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 8/50
# 146/146 - 0s - 3ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 9/50
# 146/146 - 0s - 2ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 10/50
# 146/146 - 0s - 3ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 11/50
# 146/146 - 0s - 3ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 12/50
# 146/146 - 0s - 2ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 13/50
# 146/146 - 0s - 2ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 14/50
# 146/146 - 0s - 2ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 15/50
# 146/146 - 0s - 2ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 16/50
# 146/146 - 0s - 2ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 17/50
# 146/146 - 0s - 2ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 18/50
# 146/146 - 0s - 2ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 19/50
# 146/146 - 0s - 2ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 20/50
# 146/146 - 0s - 2ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 21/50
# 146/146 - 0s - 2ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 22/50
# 146/146 - 0s - 2ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 23/50
# 146/146 - 0s - 2ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 24/50
# 146/146 - 0s - 2ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 25/50
# 146/146 - 0s - 2ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 26/50
# 146/146 - 0s - 2ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 27/50
# 146/146 - 0s - 2ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 28/50
# 146/146 - 0s - 2ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 29/50
# 146/146 - 0s - 2ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 30/50
# 146/146 - 0s - 2ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 31/50
# 146/146 - 0s - 2ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 32/50
# 146/146 - 0s - 2ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 33/50
# 146/146 - 0s - 2ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 34/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 35/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 36/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 37/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 38/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 39/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 40/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 41/50
# 146/146 - 1s - 5ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 42/50
# 146/146 - 1s - 4ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 43/50
# 146/146 - 0s - 2ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 44/50
# 146/146 - 0s - 2ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 45/50
# 146/146 - 0s - 2ms/step - loss: 9.8587e-04 - val_loss: 0.0013
# Epoch 46/50
# 146/146 - 0s - 2ms/step - loss: 9.7383e-04 - val_loss: 0.0012
# Epoch 47/50
# 146/146 - 0s - 3ms/step - loss: 9.5839e-04 - val_loss: 0.0012
# Epoch 48/50
# 146/146 - 0s - 2ms/step - loss: 9.4697e-04 - val_loss: 0.0012
# Epoch 49/50
# 146/146 - 0s - 2ms/step - loss: 9.3125e-04 - val_loss: 0.0012
# Epoch 50/50
# 146/146 - 0s - 2ms/step - loss: 9.2132e-04 - val_loss: 0.0012

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='train', linewidth = 2.5)
plt.plot(history.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
testPredict = model.predict(test_X)
print(testPredict.shape)
testPredict = testPredict.ravel()

print(testPredict.shape)
# Out:
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# (6398, 1)
# (6398,)

# %%
y_test_true = test[:,1]

# %%
import numpy as np

# %%
poll = np.array(df["temp"])

meanop = poll.mean()
stdop = poll.std()

y_test_true = y_test_true*stdop + meanop
testPredict = testPredict*stdop + meanop

# %%
rmse = np.sqrt(mean_squared_error(test_y, testPredict))
print("Test RMSE ="  ,rmse)
# Out:
# Test RMSE = 27.230965

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red", linewidth = 2.5)
plt.plot(testPredict, c = "green")
plt.title("Training data")
plt.show()

# %% [markdown]
# ### Model 2

# %%
model2 = Sequential()
model2.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model2.add(LSTM(256, activation='relu'))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.25))
model2.add(BatchNormalization())
model2.add(Dense(1, activation='linear'))

model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 256)                 │         435,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 451,969 (1.72 MB)
#  Trainable params: 451,841 (1.72 MB)
#  Non-trainable params: 128 (512.00 B)

# %%
model2.compile(loss='mse', optimizer='adam')

hist2 = model2.fit(train_X, train_y, epochs=50, batch_size=128, validation_data=(test_X, test_y))
# Out:
# Epoch 1/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 101ms/step - loss: 0.2143 - val_loss: 0.0447
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - loss: 0.0065 - val_loss: 0.0380
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 0.0047 - val_loss: 0.0318
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - loss: 0.0049 - val_loss: 0.0231
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - loss: 0.0046 - val_loss: 0.0137
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - loss: 0.0047 - val_loss: 0.0067
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 81ms/step - loss: 0.0044 - val_loss: 0.0051
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 12s 76ms/step - loss: 0.0042 - val_loss: 0.0023
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - loss: 0.0039 - val_loss: 9.2462e-04
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0039 - val_loss: 0.0030
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - loss: 0.0040 - val_loss: 0.0060
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - loss: 0.0039 - val_loss: 0.0010
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0039 - val_loss: 7.4370e-04
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0039 - val_loss: 6.2240e-04
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - loss: 0.0040 - val_loss: 5.8482e-04
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0036 - val_loss: 8.1660e-04
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0035 - val_loss: 7.3383e-04
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.0035 - val_loss: 9.6121e-04
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0032 - val_loss: 4.4296e-04
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0032 - val_loss: 6.9210e-04
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0031 - val_loss: 9.9054e-04
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0031 - val_loss: 9.6517e-04
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0032 - val_loss: 6.5071e-04
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0033 - val_loss: 5.1496e-04
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0031 - val_loss: 9.1222e-04
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0029 - val_loss: 8.8124e-04
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0031 - val_loss: 8.1285e-04
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0029 - val_loss: 4.4347e-04
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0034 - val_loss: 7.9489e-04
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0029 - val_loss: 7.8991e-04
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0029 - val_loss: 8.0694e-04
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0028 - val_loss: 9.6440e-04
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0029 - val_loss: 7.6939e-04
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0030 - val_loss: 6.2850e-04

# %%
plt.figure(figsize=(15,6))
plt.plot(hist2.history['loss'], label='train', linewidth = 2.5)
plt.plot(hist2.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
y_test_true = test[:,1]

# %%
import numpy as np

testPredict2 = model2.predict(test_X)
testPredict2 = testPredict2.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["temp"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict2 = testPredict2*stdop + meanop
# Out:
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 23.969638688724245 8.723285922487557

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict2))
print("Test(Validation) RMSE ="  ,rmse)
# Out:
# Test(Validation) RMSE = 0.66856205

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red", linewidth = 2.5)
plt.plot(testPredict2, c = "green")
plt.title("Training data")
plt.show()

# %% [markdown]
# ### Model 3

# %%
model3 = Sequential()
model3.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model3.add(LSTM(256))
model3.add(Dense(32))
model3.add(Dropout(0.25))
model3.add(BatchNormalization())
model3.add(Dense(1))
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 256)                 │         435,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           8,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 443,585 (1.69 MB)
#  Trainable params: 443,521 (1.69 MB)
#  Non-trainable params: 64 (256.00 B)

# %%
model3.compile(loss='mse', optimizer='adam')

hist3 = model3.fit(train_X, train_y, epochs=50, batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.1792 - val_loss: 0.0407
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5846 - val_loss: 0.0132
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3530 - val_loss: 0.0448
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2089 - val_loss: 0.0113
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1398 - val_loss: 0.0323
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1105 - val_loss: 0.0266
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0797 - val_loss: 0.0307
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0675 - val_loss: 0.0717
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0292 - val_loss: 0.0485
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0187 - val_loss: 0.0396
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0087 - val_loss: 0.0163
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0062 - val_loss: 0.0254
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0049 - val_loss: 0.0056
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0051 - val_loss: 0.0074
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0032 - val_loss: 0.0133
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0031 - val_loss: 0.0127
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0023 - val_loss: 0.0010
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0023 - val_loss: 6.2276e-04
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0023 - val_loss: 9.9006e-04
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 0.0191
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 7.7168e-04
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 5.0448e-04
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - val_loss: 5.0696e-04
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - val_loss: 9.5291e-04
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0017 - val_loss: 6.7211e-04
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - val_loss: 6.6826e-04
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0017 - val_loss: 4.0269e-04
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 4.4265e-04
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 9.9267e-04
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0019 - val_loss: 0.0044
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0016 - val_loss: 5.4407e-04
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 3.8468e-04
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0015 - val_loss: 4.1384e-04
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 3.7559e-04
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0013 - val_loss: 0.0037
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0014 - val_loss: 6.9343e-04
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 7.6157e-04

# %%
y_test_true = test[:,1]

# %%
testPredict3 = model3.predict(test_X)
testPredict3 = testPredict3.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["temp"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict3 = testPredict3*stdop + meanop
# Out:
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 23.969638688724245 8.723285922487557

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict3))
print("Training RMSE ="  ,rmse)
# Out:
# Training RMSE = 0.67187047

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
# plt.xlim([1000,1250])
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red")
plt.plot(testPredict3, c = "darkblue")
plt.title("Training data")
plt.show()

# %% [markdown]
# ## Saving Best Performing Model

# %%
model2.save("temp.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model2.save("temp.keras")

# %% [markdown]
# ## Forecast

# %%
# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 72  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model2.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[27.546846]
#  [27.478872]
#  [27.412111]
#  [27.346508]
#  [27.282007]
#  [27.21856 ]
#  [27.156116]
#  [27.094633]
#  [27.034065]
#  [26.97437 ]
#  [26.915504]
#  [26.857435]
#  [26.800123]
#  [26.743534]
#  [26.687632]
#  [26.632385]
#  [26.577765]
#  [26.523737]
#  [26.470276]
#  [26.417353]
#  [26.364939]
#  [26.31301 ]
#  [26.26154 ]
#  [26.210505]
#  [26.159882]
#  [26.109646]
#  [26.059776]
#  [26.01025 ]
#  [25.961046]
#  [25.912144]
#  [25.863523]
#  [25.815165]
#  [25.767048]
#  [25.719154]
#  [25.671467]
#  [25.623964]
#  [25.57663 ]
#  [25.529446]
#  [25.482395]
#  [25.43546 ]
#  [25.388622]
#  [25.341867]
#  [25.295177]
#  [25.248535]
#  [25.201923]
#  [25.155325]
#  [25.108725]
#  [25.062105]
#  [25.01545 ]
#  [24.968742]
#  [24.921967]
#  [24.875105]
#  [24.82814 ]
#  [24.781055]
#  [24.733833]
#  [24.686457]
#  [24.638906]
#  [24.591167]
#  [24.543219]
#  [24.495043]
#  [24.446623]
#  [24.397938]
#  [24.348967]
#  [24.299692]
#  [24.250093]
#  [24.20015 ]
#  [24.149837]
#  [24.099136]
#  [24.048023]
#  [23.996475]
#  [23.94447 ]
#  [23.89198 ]]

# %%
orignal = pd.read_csv("../forecast_data/weather_forecast.csv")

# %%
np.sqrt(mean_squared_error(orignal['app_temp'], forecast_values))
# Out:
# 5.089368409052854
