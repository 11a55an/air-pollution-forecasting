# %% [markdown]
# # Data Conversion

# %% [markdown]
# ## Weather Data

# %%
import json

# Load JSON data from file with explicit encoding
with open('data_airquality.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# %%
# Convert JSON data into pandas DataFrame
df = pd.json_normalize(data, 'data')

# %%
df.head()
# Out:
#    app_temp  azimuth  clouds       datetime  dewpt  dhi  dni  elev_angle  ghi  \
# 0      24.5      4.3       0  2023-09-30:19   19.0    0    0       -60.6    0
# 1      23.0     32.2       0  2023-09-30:20   18.6    0    0       -56.6    0
# 2      22.6     52.5       0  2023-09-30:21   18.6    0    0       -48.0    0
# 3      21.4     66.5       0  2023-09-30:22   18.1    0    0       -37.1    0
# 4      21.0     77.0       0  2023-09-30:23   18.1    0    0       -25.1    0
#
#   h_angle  ...        timestamp_utc          ts   uv vis  wind_dir  \
# 0    None  ...  2023-09-30T19:00:00  1696100400  0.0  10       284
# 1    None  ...  2023-09-30T20:00:00  1696104000  0.0  10       290
# 2    None  ...  2023-09-30T21:00:00  1696107600  0.0  10       300
# 3    None  ...  2023-09-30T22:00:00  1696111200  0.0  10       290
# 4    None  ...  2023-09-30T23:00:00  1696114800  0.0  10       300
#
#    wind_gust_spd  wind_spd  weather.description  weather.code weather.icon
# 0            3.2       2.0            Clear Sky           800         c01n
# 1            3.2       2.0            Clear Sky           800         c01n
# 2            3.2       1.6            Clear Sky           800         c01n
# 3            2.8       2.0            Clear Sky           800         c01n
# 4            2.8       2.4            Clear Sky           800         c01n
#
# [5 rows x 30 columns]

# %%
df = df.sort_values(by='datetime').reset_index(drop=True)

df.head()
# Out:
#    app_temp  azimuth  clouds       datetime  dewpt  dhi  dni  elev_angle  ghi  \
# 0      24.5      4.3       0  2023-09-30:19   19.0    0    0       -60.6    0
# 1      23.0     32.2       0  2023-09-30:20   18.6    0    0       -56.6    0
# 2      22.6     52.5       0  2023-09-30:21   18.6    0    0       -48.0    0
# 3      21.4     66.5       0  2023-09-30:22   18.1    0    0       -37.1    0
# 4      21.0     77.0       0  2023-09-30:23   18.1    0    0       -25.1    0
#
#   h_angle  ...        timestamp_utc          ts   uv vis  wind_dir  \
# 0    None  ...  2023-09-30T19:00:00  1696100400  0.0  10       284
# 1    None  ...  2023-09-30T20:00:00  1696104000  0.0  10       290
# 2    None  ...  2023-09-30T21:00:00  1696107600  0.0  10       300
# 3    None  ...  2023-09-30T22:00:00  1696111200  0.0  10       290
# 4    None  ...  2023-09-30T23:00:00  1696114800  0.0  10       300
#
#    wind_gust_spd  wind_spd  weather.description  weather.code weather.icon
# 0            3.2       2.0            Clear Sky           800         c01n
# 1            3.2       2.0            Clear Sky           800         c01n
# 2            3.2       1.6            Clear Sky           800         c01n
# 3            2.8       2.0            Clear Sky           800         c01n
# 4            2.8       2.4            Clear Sky           800         c01n
#
# [5 rows x 30 columns]

# %%
# Drop all columns except 'temp' and 'timestamp_local'
df = df[['temp', 'timestamp_local']]

# %%
df.to_csv("oct_23.csv", index=False)

# %% [markdown]
# ## Pollution Data

# %%
import pandas as pd

# Load the JSON file into a Pandas DataFrame
df = pd.read_json('data_airquality.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 # Load the JSON file into a Pandas DataFrame
# ----> 4 df = pd.read_json('data_airquality.json')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
#    1026 if self.dtype_backend is not lib.no_default:
#    1027     return obj.convert_dtypes(
#    1028         infer_objects=False, dtype_backend=self.dtype_backend
#    1029     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\json\_json.py:1051, in JsonReader._get_object_parser(self, json)
#    1049 obj = None
#    1050 if typ == "frame":
# -> 1051     obj = FrameParser(json, **kwargs).parse()
#    1053 if typ == "series" or obj is None:
#    1054     if not isinstance(dtype, bool):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\json\_json.py:1187, in Parser.parse(self)
#    1185 @final
#    1186 def parse(self):
# -> 1187     self._parse()
#    1189     if self.obj is None:
#    1190         return None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\json\_json.py:1399, in FrameParser._parse(self)
#    1396 orient = self.orient
#    1398 if orient == "columns":
# -> 1399     self.obj = DataFrame(
#    1400         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1401     )
#    1402 elif orient == "split":
#    1403     decoded = {
#    1404         str(k): v
#    1405         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1406     }
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
df.to_csv("dummy.csv")

# %%
# Separate the JSON data into individual columns
df = pd.concat([df.drop(['data'], axis=1), pd.json_normalize(df['data'])], axis=1)

# %%
df = df.sort_values(by='datetime').reset_index(drop=True)

df.head()
# Out:
#   city_name country_code       lat       lon  state_code      timezone  aqi  \
# 0    Gujrāt           PK  32.57284  74.07897           4  Asia/Karachi  121
# 1    Gujrāt           PK  32.57284  74.07897           4  Asia/Karachi  117
# 2    Gujrāt           PK  32.57284  74.07897           4  Asia/Karachi  112
# 3    Gujrāt           PK  32.57284  74.07897           4  Asia/Karachi  114
# 4    Gujrāt           PK  32.57284  74.07897           4  Asia/Karachi  116
#
#       co       datetime   no2    o3  pm10   pm25   so2      timestamp_local  \
# 0  242.0  2024-01-30:19  16.0  45.3  77.3  43.33  24.0  2024-01-31T00:00:00
# 1  209.7  2024-01-30:20  13.0  44.7  75.7  41.67  19.0  2024-01-31T01:00:00
# 2  177.4  2024-01-30:21  10.0  44.0  74.0  40.00  14.0  2024-01-31T02:00:00
# 3  163.4  2024-01-30:22   8.7  44.7  79.3  40.67  12.7  2024-01-31T03:00:00
# 4  149.4  2024-01-30:23   7.3  45.3  84.7  41.33  11.3  2024-01-31T04:00:00
#
#          timestamp_utc          ts
# 0  2024-01-30T19:00:00  1706641200
# 1  2024-01-30T20:00:00  1706644800
# 2  2024-01-30T21:00:00  1706648400
# 3  2024-01-30T22:00:00  1706652000
# 4  2024-01-30T23:00:00  1706655600

# %%
data = pd.concat([data, df], ignore_index=True)

# %%
data.shape
# Out:
# (7763, 17)

# %%
data = data.sort_values(by='datetime').reset_index(drop=True)

data.head()
# Out:
#   city_name country_code       lat       lon  state_code      timezone    aqi  \
# 0    Gujrāt           PK  32.57284  74.07897           4  Asia/Karachi  385.0
# 1    Gujrāt           PK  32.57284  74.07897           4  Asia/Karachi  404.0
# 2    Gujrāt           PK  32.57284  74.07897           4  Asia/Karachi  421.0
# 3    Gujrāt           PK  32.57284  74.07897           4  Asia/Karachi  425.0
# 4    Gujrāt           PK  32.57284  74.07897           4  Asia/Karachi  430.0
#
#        co       datetime   no2    o3   pm10    pm25    so2  \
# 0  1339.8  2022-01-31:19  76.0  10.7  491.7  347.67  238.0
# 1  1437.6  2022-01-31:20  76.0   9.3  508.3  359.33  268.0
# 2  1535.5  2022-01-31:21  76.0   8.0  525.0  371.00  298.0
# 3  1659.0  2022-01-31:22  68.3   5.3  529.3  374.00  275.7
# 4  1782.5  2022-01-31:23  60.7   2.7  533.7  377.00  253.3
#
#        timestamp_local        timestamp_utc          ts
# 0  2022-02-01T00:00:00  2022-01-31T19:00:00  1643655600
# 1  2022-02-01T01:00:00  2022-01-31T20:00:00  1643659200
# 2  2022-02-01T02:00:00  2022-01-31T21:00:00  1643662800
# 3  2022-02-01T03:00:00  2022-01-31T22:00:00  1643666400
# 4  2022-02-01T04:00:00  2022-01-31T23:00:00  1643670000

# %%
data_1 = pd.read_csv("data_2022.csv")

# %%
data_2 = pd.read_csv("data_2023.csv")

# %%
data_1.shape
# Out:
# (7763, 10)

# %%
data_2.shape
# Out:
# (9181, 10)

# %%
data = pd.concat([data_1, data_2], ignore_index=True)

# %%
data.shape
# Out:
# (16944, 10)

# %%
data.head()
# Out:
#   city_name country_code       lat       lon  state_code      timezone    aqi  \
# 0    Gujrāt           PK  32.57284  74.07897         4.0  Asia/Karachi  385.0
# 1    Gujrāt           PK  32.57284  74.07897         4.0  Asia/Karachi  404.0
# 2    Gujrāt           PK  32.57284  74.07897         4.0  Asia/Karachi  421.0
# 3    Gujrāt           PK  32.57284  74.07897         4.0  Asia/Karachi  425.0
# 4    Gujrāt           PK  32.57284  74.07897         4.0  Asia/Karachi  430.0
#
#        co       datetime   no2    o3   pm10    pm25    so2  \
# 0  1339.8  2022-01-31:19  76.0  10.7  491.7  347.67  238.0
# 1  1437.6  2022-01-31:20  76.0   9.3  508.3  359.33  268.0
# 2  1535.5  2022-01-31:21  76.0   8.0  525.0  371.00  298.0
# 3  1659.0  2022-01-31:22  68.3   5.3  529.3  374.00  275.7
# 4  1782.5  2022-01-31:23  60.7   2.7  533.7  377.00  253.3
#
#        timestamp_local        timestamp_utc          ts  Unnamed: 0
# 0  2022-02-01T00:00:00  2022-01-31T19:00:00  1643655600         NaN
# 1  2022-02-01T01:00:00  2022-01-31T20:00:00  1643659200         NaN
# 2  2022-02-01T02:00:00  2022-01-31T21:00:00  1643662800         NaN
# 3  2022-02-01T03:00:00  2022-01-31T22:00:00  1643666400         NaN
# 4  2022-02-01T04:00:00  2022-01-31T23:00:00  1643670000         NaN

# %%
data.to_csv("data.csv")

# %% [markdown]
# ## Merge Data

# %%
import pandas as pd

# Load CSV files into pandas DataFrames
df_weather = pd.read_csv('data_weather.csv')
df_aqi = pd.read_csv('data_aqi.csv')

# Merge DataFrames on 'timestamp_local' column
merged_df = pd.merge(df_weather, df_aqi, on='timestamp_local')

# %%
merged_df.head()
# Out:
#    temp      timestamp_local city_name country_code    aqi      co   no2  \
# 0  12.6  2022-02-01T00:00:00    Gujrāt           PK  385.0  1339.8  76.0
# 1  11.5  2022-02-01T01:00:00    Gujrāt           PK  404.0  1437.6  76.0
# 2  11.9  2022-02-01T02:00:00    Gujrāt           PK  421.0  1535.5  76.0
# 3  12.2  2022-02-01T03:00:00    Gujrāt           PK  425.0  1659.0  68.3
# 4  11.9  2022-02-01T04:00:00    Gujrāt           PK  430.0  1782.5  60.7
#
#      o3   pm10    pm25    so2
# 0  10.7  491.7  347.67  238.0
# 1   9.3  508.3  359.33  268.0
# 2   8.0  525.0  371.00  298.0
# 3   5.3  529.3  374.00  275.7
# 4   2.7  533.7  377.00  253.3

# %%
merged_df.to_csv("data_final.csv",index=False)

# %% [markdown]
# ## Check Missing Hours

# %%
import pandas as pd

# Load CSV file into pandas DataFrame
df = pd.read_csv('data_final.csv')

# Convert 'timestamp_local' column to datetime
df['timestamp_local'] = pd.to_datetime(df['timestamp_local'])

# Sort DataFrame by 'timestamp_local'
df = df.sort_values(by='timestamp_local')
# Reset index after sorting
df = df.reset_index(drop=True)
# Calculate difference between consecutive timestamps
time_diff = df['timestamp_local'].diff()

# Check for missing hours
missing_hours = time_diff[time_diff != pd.Timedelta(hours=1)]

if missing_hours.empty:
    print("No missing hours.")
else:
    print("Missing hours:")
    print(missing_hours)
# Out:
# Missing hours:
# 0         NaT
# 5809   0 days
# 7274   0 days
# Name: timestamp_local, dtype: timedelta64[ns]

# %%
missing_indices = time_diff[time_diff != pd.Timedelta(hours=1)].index

# Display the indices
print("Indices of missing hours:", missing_indices)
# Out:
# Indices of missing hours: Index([0, 5809, 7274], dtype='int64')

# %%
print(df_weather.iloc[5800:5810])
# Out:
#       temp      timestamp_local
# 5800  34.8  2022-09-30T16:00:00
# 5801  34.8  2022-09-30T17:00:00
# 5802  33.3  2022-09-30T18:00:00
# 5803  31.5  2022-09-30T19:00:00
# 5804  31.5  2022-09-30T20:00:00
# 5805  30.4  2022-09-30T21:00:00
# 5806  28.9  2022-09-30T22:00:00
# 5807  29.6  2022-09-30T23:00:00
# 5808  28.9  2022-10-01T00:00:00
# 5809  27.4  2022-10-01T01:00:00

# %%
import pandas as pd

# Load CSV files into pandas DataFrames
df_aqi = pd.read_csv('data_aqi.csv')
df_weather = pd.read_csv('data_weather.csv')

# Extract 'timestamp_local' column from each DataFrame
timestamps_aqi = df_aqi['timestamp_local']
timestamps_weather = df_weather['timestamp_local']

# Find missing indices in df_weather
missing_indices_weather = timestamps_aqi[~timestamps_aqi.isin(timestamps_weather)].index

# Find missing indices in df_aqi
missing_indices_aqi = timestamps_weather[~timestamps_weather.isin(timestamps_aqi)].index

print("Missing indices in data_weather.csv:", missing_indices_weather)
print("Missing indices in data_aqi.csv:", missing_indices_aqi)
# Out:
# Missing indices in data_weather.csv: Index([], dtype='int64')
# Missing indices in data_aqi.csv: Index([], dtype='int64')

# %%
# Drop duplicates based on 'timestamp_local' column
df_weather = df_weather.drop_duplicates(subset=['timestamp_local'])

# Reset index
df_weather = df_weather.reset_index(drop=True)

# %%
df_weather.shape
# Out:
# (18216, 2)

# %%
# Drop duplicates based on 'timestamp_local' column
df_aqi = df_aqi.drop_duplicates(subset=['timestamp_local'])

# Reset index
df_aqi = df_aqi.reset_index(drop=True)

# %%
df_aqi.shape
# Out:
# (18216, 10)

# %%
df_aqi.to_csv("data_aqi.csv",index=False)

# %%
df_weather.to_csv("data_weather.csv",index=False)
