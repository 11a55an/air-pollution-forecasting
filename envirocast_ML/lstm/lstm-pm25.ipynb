# %% [markdown]
# # LSTM - PM2.5

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/data_imputed.csv")

# %%
data = df[['pm25']]

# %% [markdown]
# ## Data PreProcessing

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
dataset = data
values = dataset.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
def series_to_supervised(data, n_in = 1, n_out = 1, dropnan = True):
    n_vars = 1 if type(data) is list else data.shape[1]
    
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
        
    return agg

# %%
# converting the dataset as supervised learning
reframed = series_to_supervised(scaled, 168, 1)
print(reframed.shape)
# Out:
# (19514, 169)

# %%
reframed.head()
# Out:
#      var1(t-168)  var1(t-167)  var1(t-166)  var1(t-165)  var1(t-164)  \
# 168     0.580246     0.599990     0.619751     0.624831     0.629911
# 169     0.599990     0.619751     0.624831     0.629911     0.634991
# 170     0.619751     0.624831     0.629911     0.634991     0.632163
# 171     0.624831     0.629911     0.634991     0.632163     0.629352
# 172     0.629911     0.634991     0.632163     0.629352     0.626524
#
#      var1(t-163)  var1(t-162)  var1(t-161)  var1(t-160)  var1(t-159)  ...  \
# 168     0.634991     0.632163     0.629352     0.626524     0.544111  ...
# 169     0.632163     0.629352     0.626524     0.544111     0.461714  ...
# 170     0.629352     0.626524     0.544111     0.461714     0.379301  ...
# 171     0.626524     0.544111     0.461714     0.379301     0.297463  ...
# 172     0.544111     0.461714     0.379301     0.297463     0.215609  ...
#
#      var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  \
# 168   0.154650   0.184012   0.213357   0.273757   0.334140   0.394541
# 169   0.184012   0.213357   0.273757   0.334140   0.394541   0.428407
# 170   0.213357   0.273757   0.334140   0.394541   0.428407   0.462273
# 171   0.273757   0.334140   0.394541   0.428407   0.462273   0.496139
# 172   0.334140   0.394541   0.428407   0.462273   0.496139   0.518152
#
#      var1(t-3)  var1(t-2)  var1(t-1)   var1(t)
# 168   0.428407   0.462273   0.496139  0.518152
# 169   0.462273   0.496139   0.518152  0.540165
# 170   0.496139   0.518152   0.540165  0.562178
# 171   0.518152   0.540165   0.562178  0.531140
# 172   0.540165   0.562178   0.531140  0.500085
#
# [5 rows x 169 columns]

# %%
reframed.columns
# Out:
# Index(['var1(t-168)', 'var1(t-167)', 'var1(t-166)', 'var1(t-165)',
#        'var1(t-164)', 'var1(t-163)', 'var1(t-162)', 'var1(t-161)',
#        'var1(t-160)', 'var1(t-159)',
#        ...
#        'var1(t-9)', 'var1(t-8)', 'var1(t-7)', 'var1(t-6)', 'var1(t-5)',
#        'var1(t-4)', 'var1(t-3)', 'var1(t-2)', 'var1(t-1)', 'var1(t)'],
#       dtype='object', length=169)

# %%
values = reframed.values

# We train the model on the 1st 3 years and then test on the last year (for now)
n_train_hours = int(365 * 24 * 1.5)

train = values[:n_train_hours, :]
test = values[n_train_hours:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D :- (no.of samples, no.of timesteps, no.of features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (13140, 1, 168) (13140,) (6374, 1, 168) (6374,)

# %%
train.shape, test.shape, values.shape
# Out:
# ((13140, 169), (6374, 169), (19514, 169))

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# ### Model 1

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(64))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          59,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 59,713 (233.25 KB)
#  Trainable params: 59,713 (233.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_split=0.2, verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 146/146 - 2s - 14ms/step - loss: 0.0106 - val_loss: 2.9158e-04
# Epoch 2/50
# 146/146 - 0s - 2ms/step - loss: 0.0029 - val_loss: 2.3766e-04
# Epoch 3/50
# 146/146 - 0s - 2ms/step - loss: 0.0022 - val_loss: 2.0677e-04
# Epoch 4/50
# 146/146 - 0s - 2ms/step - loss: 0.0018 - val_loss: 1.6886e-04
# Epoch 5/50
# 146/146 - 0s - 2ms/step - loss: 0.0016 - val_loss: 1.4920e-04
# Epoch 6/50
# 146/146 - 0s - 2ms/step - loss: 0.0017 - val_loss: 1.3716e-04
# Epoch 7/50
# 146/146 - 0s - 2ms/step - loss: 0.0016 - val_loss: 1.1960e-04
# Epoch 8/50
# 146/146 - 0s - 2ms/step - loss: 0.0013 - val_loss: 1.0867e-04
# Epoch 9/50
# 146/146 - 0s - 2ms/step - loss: 0.0012 - val_loss: 1.0697e-04
# Epoch 10/50
# 146/146 - 0s - 2ms/step - loss: 0.0013 - val_loss: 1.0362e-04
# Epoch 11/50
# 146/146 - 0s - 2ms/step - loss: 0.0013 - val_loss: 9.9021e-05
# Epoch 12/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 1.0147e-04
# Epoch 13/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 1.0976e-04
# Epoch 14/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 1.1173e-04
# Epoch 15/50
# 146/146 - 0s - 2ms/step - loss: 0.0011 - val_loss: 1.0676e-04
# Epoch 16/50
# 146/146 - 0s - 2ms/step - loss: 0.0010 - val_loss: 1.0955e-04
# Epoch 17/50
# 146/146 - 0s - 2ms/step - loss: 9.4085e-04 - val_loss: 1.1924e-04
# Epoch 18/50
# 146/146 - 0s - 2ms/step - loss: 9.6742e-04 - val_loss: 1.2459e-04
# Epoch 19/50
# 146/146 - 0s - 2ms/step - loss: 9.8082e-04 - val_loss: 1.2040e-04
# Epoch 20/50
# 146/146 - 0s - 2ms/step - loss: 9.1161e-04 - val_loss: 1.1984e-04
# Epoch 21/50
# 146/146 - 0s - 2ms/step - loss: 8.5467e-04 - val_loss: 1.2679e-04
# Epoch 22/50
# 146/146 - 0s - 2ms/step - loss: 8.6468e-04 - val_loss: 1.3368e-04
# Epoch 23/50
# 146/146 - 0s - 2ms/step - loss: 8.8477e-04 - val_loss: 1.3222e-04
# Epoch 24/50
# 146/146 - 0s - 2ms/step - loss: 8.4634e-04 - val_loss: 1.2791e-04
# Epoch 25/50
# 146/146 - 0s - 2ms/step - loss: 7.8955e-04 - val_loss: 1.2969e-04
# Epoch 26/50
# 146/146 - 0s - 2ms/step - loss: 7.8041e-04 - val_loss: 1.3548e-04
# Epoch 27/50
# 146/146 - 0s - 2ms/step - loss: 8.0300e-04 - val_loss: 1.3843e-04
# Epoch 28/50
# 146/146 - 0s - 3ms/step - loss: 7.9816e-04 - val_loss: 1.3398e-04
# Epoch 29/50
# 146/146 - 1s - 5ms/step - loss: 7.4926e-04 - val_loss: 1.3010e-04
# Epoch 30/50
# 146/146 - 0s - 2ms/step - loss: 7.1602e-04 - val_loss: 1.3152e-04
# Epoch 31/50
# 146/146 - 0s - 2ms/step - loss: 7.2389e-04 - val_loss: 1.3607e-04
# Epoch 32/50
# 146/146 - 0s - 2ms/step - loss: 7.4306e-04 - val_loss: 1.3720e-04
# Epoch 33/50
# 146/146 - 0s - 2ms/step - loss: 7.2710e-04 - val_loss: 1.3196e-04
# Epoch 34/50
# 146/146 - 1s - 5ms/step - loss: 6.8249e-04 - val_loss: 1.2792e-04
# Epoch 35/50
# 146/146 - 0s - 2ms/step - loss: 6.6048e-04 - val_loss: 1.2874e-04
# Epoch 36/50
# 146/146 - 0s - 2ms/step - loss: 6.7159e-04 - val_loss: 1.3262e-04
# Epoch 37/50
# 146/146 - 0s - 2ms/step - loss: 6.8725e-04 - val_loss: 1.3335e-04
# Epoch 38/50
# 146/146 - 0s - 2ms/step - loss: 6.7098e-04 - val_loss: 1.2834e-04
# Epoch 39/50
# 146/146 - 0s - 2ms/step - loss: 6.3267e-04 - val_loss: 1.2421e-04
# Epoch 40/50
# 146/146 - 0s - 2ms/step - loss: 6.1410e-04 - val_loss: 1.2443e-04
# Epoch 41/50
# 146/146 - 0s - 2ms/step - loss: 6.2269e-04 - val_loss: 1.2753e-04
# Epoch 42/50
# 146/146 - 0s - 2ms/step - loss: 6.3547e-04 - val_loss: 1.2829e-04
# Epoch 43/50
# 146/146 - 0s - 2ms/step - loss: 6.2388e-04 - val_loss: 1.2418e-04
# Epoch 44/50
# 146/146 - 0s - 2ms/step - loss: 5.9314e-04 - val_loss: 1.2022e-04
# Epoch 45/50
# 146/146 - 0s - 2ms/step - loss: 5.7517e-04 - val_loss: 1.1975e-04
# Epoch 46/50
# 146/146 - 0s - 2ms/step - loss: 5.7863e-04 - val_loss: 1.2179e-04
# Epoch 47/50
# 146/146 - 0s - 2ms/step - loss: 5.8796e-04 - val_loss: 1.2254e-04
# Epoch 48/50
# 146/146 - 0s - 2ms/step - loss: 5.8209e-04 - val_loss: 1.1964e-04
# Epoch 49/50
# 146/146 - 0s - 2ms/step - loss: 5.6007e-04 - val_loss: 1.1614e-04
# Epoch 50/50
# 146/146 - 0s - 2ms/step - loss: 5.4283e-04 - val_loss: 1.1496e-04

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='train', linewidth = 2.5)
plt.plot(history.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
testPredict = model.predict(test_X)
print(testPredict.shape)
testPredict = testPredict.ravel()

print(testPredict.shape)
# Out:
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# (6374, 1)
# (6374,)

# %%
y_test_true = test[:,1]

# %%
import numpy as np

# %%
poll = np.array(df["pm25"])

meanop = poll.mean()
stdop = poll.std()

y_test_true = y_test_true*stdop + meanop
testPredict = testPredict*stdop + meanop

# %%
rmse = np.sqrt(mean_squared_error(test_y, testPredict))
print("Test RMSE ="  ,rmse)
# Out:
# Test RMSE = 83.36279

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red", linewidth = 2.5)
plt.plot(testPredict, c = "green")
plt.title("Training data")
plt.show()

# %% [markdown]
# ### Model 2

# %%
model2 = Sequential()
model2.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model2.add(LSTM(256))
model2.add(Dense(64))
model2.add(Dropout(0.25))
model2.add(BatchNormalization())
model2.add(Dense(1))

model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 256)                 │         435,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 451,969 (1.72 MB)
#  Trainable params: 451,841 (1.72 MB)
#  Non-trainable params: 128 (512.00 B)

# %%
model2.compile(loss='mse', optimizer='adam')

hist2 = model2.fit(train_X, train_y, epochs=50, batch_size=128, validation_data=(test_X, test_y))
# Out:
# Epoch 1/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.5541 - val_loss: 0.0117
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0502 - val_loss: 0.0068
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0124 - val_loss: 0.0049
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0050 - val_loss: 0.0022
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0038 - val_loss: 9.9774e-04
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0030 - val_loss: 1.0662e-04
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0025 - val_loss: 9.7364e-04
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022 - val_loss: 2.1551e-04
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0021 - val_loss: 6.8658e-04
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0019 - val_loss: 1.1506e-04
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 5.6385e-04
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0016 - val_loss: 9.2890e-05
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0015 - val_loss: 1.0661e-04
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014 - val_loss: 4.0621e-04
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0012 - val_loss: 2.3145e-04
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0012 - val_loss: 1.7377e-04
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0012 - val_loss: 2.7658e-04
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 1.3809e-04
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0011 - val_loss: 1.2176e-04
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 1.5291e-04
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 8.9806e-04 - val_loss: 7.5981e-04
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0010 - val_loss: 8.1027e-04
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 5.4941e-05
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7488e-04 - val_loss: 4.8740e-04
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.9702e-04 - val_loss: 1.8384e-04
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.1882e-04 - val_loss: 2.6965e-04
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.1761e-04 - val_loss: 0.0020
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.6629e-04 - val_loss: 9.6037e-05
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.1624e-04 - val_loss: 2.1254e-04
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9914e-04 - val_loss: 9.9472e-05
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.5409e-04 - val_loss: 6.8235e-04
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9588e-04 - val_loss: 2.2012e-04
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.8016e-04 - val_loss: 1.9160e-04
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1193e-04 - val_loss: 5.1692e-04
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.9327e-04 - val_loss: 7.2190e-04
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.9540e-04 - val_loss: 0.0014
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.7670e-04 - val_loss: 2.9873e-04
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.3639e-04 - val_loss: 3.9619e-04
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3898e-04 - val_loss: 3.4517e-04
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.9857e-04 - val_loss: 8.5017e-05
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.2546e-04 - val_loss: 4.4558e-05
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.9159e-04 - val_loss: 6.9013e-05
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.3695e-04 - val_loss: 1.3557e-04
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.2778e-04 - val_loss: 1.0439e-04
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.5737e-04 - val_loss: 3.8800e-04
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.6010e-04 - val_loss: 4.9578e-05
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.6782e-04 - val_loss: 8.6719e-05

# %%
plt.figure(figsize=(15,6))
plt.plot(hist2.history['loss'], label='train', linewidth = 2.5)
plt.plot(hist2.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
y_test_true = test[:,1]

# %%
testPredict2 = model2.predict(test_X)
testPredict2 = testPredict2.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pm25"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict2 = testPredict2*stdop + meanop
# Out:
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 78.72209429935984 64.31464672885156

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict2))
print("Test(Validation) RMSE ="  ,rmse)
# Out:
# Test(Validation) RMSE = 3.4512532

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red", linewidth = 2.5)
plt.plot(testPredict2, c = "green")
plt.title("Training data")
plt.show()

# %%
model2.save("pm25.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model2.save("pm25.keras")

# %% [markdown]
# ### Model 3

# %%
model3 = Sequential()
model3.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model3.add(LSTM(256))
model3.add(Dense(32))
model3.add(Dropout(0.25))
model3.add(BatchNormalization())
model3.add(Dense(1))
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 256)                 │         435,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           8,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 443,585 (1.69 MB)
#  Trainable params: 443,521 (1.69 MB)
#  Non-trainable params: 64 (256.00 B)

# %%
model3.compile(loss='mse', optimizer='adam')

hist3 = model3.fit(train_X, train_y, epochs=50, batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - loss: 0.8617 - val_loss: 0.0124
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2823 - val_loss: 0.0041
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1030 - val_loss: 0.0041
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0311 - val_loss: 0.0059
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0310 - val_loss: 0.0056
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0120 - val_loss: 0.0055
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0071 - val_loss: 0.0056
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0045 - val_loss: 0.0036
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0048 - val_loss: 0.0028
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0025 - val_loss: 0.0010
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0024 - val_loss: 4.9552e-04
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024 - val_loss: 4.4960e-04
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0030 - val_loss: 5.8840e-05
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0022 - val_loss: 6.3738e-04
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0020 - val_loss: 1.7765e-04
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - val_loss: 1.7306e-04
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0020 - val_loss: 1.3868e-04
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0024 - val_loss: 1.9817e-04
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017 - val_loss: 5.3148e-05
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - val_loss: 3.3600e-04
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 9.9242e-04
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - val_loss: 2.6691e-04
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015 - val_loss: 5.4007e-04
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 1.6204e-04
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 8.7708e-04
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 8.2535e-05
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 1.2712e-04
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 4.7573e-04
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 1.3590e-04
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022 - val_loss: 1.5260e-04
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0023 - val_loss: 3.6519e-04
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - val_loss: 2.4744e-04
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - val_loss: 3.6109e-04
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - val_loss: 3.6264e-05
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 5.6817e-05
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.6863e-04 - val_loss: 5.0470e-05
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 9.8855e-04
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 1.3176e-04
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - val_loss: 7.3674e-04
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0021 - val_loss: 8.4726e-04

# %%
y_test_true = test[:,1]

# %%
testPredict3 = model3.predict(test_X)
testPredict3 = testPredict3.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pm25"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict3 = testPredict3*stdop + meanop
# Out:
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 78.72209429935984 64.31464672885156

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict3))
print("Training RMSE ="  ,rmse)
# Out:
# Training RMSE = 4.111489

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
# plt.xlim([1000,1250])
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red")
plt.plot(testPredict3, c = "darkblue")
plt.title("Training data")
plt.show()

# %% [markdown]
# ## Forecast

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[27.132513]
#  [27.208662]
#  [27.279833]
#  [27.346386]
#  [27.408646]
#  [27.466913]
#  [27.521463]]

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model2.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[27.009602]
#  [26.968103]
#  [26.926489]
#  [26.884745]
#  [26.842861]
#  [26.800823]
#  [26.758621]]

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model3.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[27.136915]
#  [27.216236]
#  [27.289446]
#  [27.356995]
#  [27.419304]
#  [27.476767]
#  [27.529747]]
