# %% [markdown]
# # LSTM - SO2

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/data_imputed.csv")

# %%
df['timestamp_local'] = pd.to_datetime(df['timestamp_local'])

# %%
df = df[['timestamp_local','temp','aqi','co','no2','o3','pm10','pm25','so2']]

# %%
df.head()
# Out:
#       timestamp_local  temp    aqi      co   no2    o3   pm10    pm25    so2
# 0 2022-02-01 00:00:00  12.6  385.0  1339.8  76.0  10.7  491.7  347.67  238.0
# 1 2022-02-01 01:00:00  11.5  404.0  1437.6  76.0   9.3  508.3  359.33  268.0
# 2 2022-02-01 02:00:00  11.9  421.0  1535.5  76.0   8.0  525.0  371.00  298.0
# 3 2022-02-01 03:00:00  12.2  425.0  1659.0  68.3   5.3  529.3  374.00  275.7
# 4 2022-02-01 04:00:00  11.9  430.0  1782.5  60.7   2.7  533.7  377.00  253.3

# %%
data = df[['so2']]

# %% [markdown]
# ## Data PreProcessing

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
dataset = data
values = dataset.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
def series_to_supervised(data, n_in = 1, n_out = 1, dropnan = True):
    n_vars = 1 if type(data) is list else data.shape[1]
    
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
        
    return agg

# %%
# converting the dataset as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
print(reframed.shape)
# Out:
# (18217, 2)

# %%
reframed.head()
# Out:
#    var1(t-1)   var1(t)
# 1   0.610256  0.687180
# 2   0.687180  0.764103
# 3   0.764103  0.706923
# 4   0.706923  0.649487
# 5   0.649487  0.592308

# %%
reframed.columns
# Out:
# Index(['var1(t-1)', 'var1(t)'], dtype='object')

# %%
values = reframed.values

# We train the model on the 1st 3 years and then test on the last year (for now)
n_train_hours = int(365 * 24 * 1.5)

train = values[:n_train_hours, :]
test = values[n_train_hours:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D :- (no.of samples, no.of timesteps, no.of features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (13140, 1, 1) (13140,) (5077, 1, 1) (5077,)

# %%
train.shape, test.shape, values.shape
# Out:
# ((13140, 2), (5077, 2), (18217, 2))

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# ### Model 1

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(64))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_split=0.2, verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 146/146 - 3s - 22ms/step - loss: 0.0247 - val_loss: 9.4357e-04
# Epoch 2/50
# 146/146 - 1s - 5ms/step - loss: 0.0132 - val_loss: 4.4555e-04
# Epoch 3/50
# 146/146 - 1s - 5ms/step - loss: 0.0070 - val_loss: 1.8015e-04
# Epoch 4/50
# 146/146 - 1s - 5ms/step - loss: 0.0028 - val_loss: 6.5473e-05
# Epoch 5/50
# 146/146 - 0s - 3ms/step - loss: 0.0013 - val_loss: 4.1878e-05
# Epoch 6/50
# 146/146 - 0s - 3ms/step - loss: 0.0010 - val_loss: 3.6862e-05
# Epoch 7/50
# 146/146 - 1s - 5ms/step - loss: 9.8336e-04 - val_loss: 3.5707e-05
# Epoch 8/50
# 146/146 - 0s - 3ms/step - loss: 9.7761e-04 - val_loss: 3.5398e-05
# Epoch 9/50
# 146/146 - 0s - 3ms/step - loss: 9.7480e-04 - val_loss: 3.5212e-05
# Epoch 10/50
# 146/146 - 1s - 5ms/step - loss: 9.7235e-04 - val_loss: 3.4979e-05
# Epoch 11/50
# 146/146 - 1s - 4ms/step - loss: 9.6988e-04 - val_loss: 3.4693e-05
# Epoch 12/50
# 146/146 - 0s - 3ms/step - loss: 9.6733e-04 - val_loss: 3.4390e-05
# Epoch 13/50
# 146/146 - 0s - 3ms/step - loss: 9.6465e-04 - val_loss: 3.4099e-05
# Epoch 14/50
# 146/146 - 1s - 5ms/step - loss: 9.6182e-04 - val_loss: 3.3826e-05
# Epoch 15/50
# 146/146 - 1s - 4ms/step - loss: 9.5888e-04 - val_loss: 3.3568e-05
# Epoch 16/50
# 146/146 - 1s - 5ms/step - loss: 9.5587e-04 - val_loss: 3.3317e-05
# Epoch 17/50
# 146/146 - 0s - 3ms/step - loss: 9.5291e-04 - val_loss: 3.3060e-05
# Epoch 18/50
# 146/146 - 0s - 3ms/step - loss: 9.5008e-04 - val_loss: 3.2790e-05
# Epoch 19/50
# 146/146 - 1s - 5ms/step - loss: 9.4743e-04 - val_loss: 3.2515e-05
# Epoch 20/50
# 146/146 - 1s - 5ms/step - loss: 9.4499e-04 - val_loss: 3.2261e-05
# Epoch 21/50
# 146/146 - 0s - 3ms/step - loss: 9.4278e-04 - val_loss: 3.2046e-05
# Epoch 22/50
# 146/146 - 0s - 3ms/step - loss: 9.4080e-04 - val_loss: 3.1881e-05
# Epoch 23/50
# 146/146 - 0s - 3ms/step - loss: 9.3905e-04 - val_loss: 3.1759e-05
# Epoch 24/50
# 146/146 - 0s - 3ms/step - loss: 9.3756e-04 - val_loss: 3.1673e-05
# Epoch 25/50
# 146/146 - 0s - 3ms/step - loss: 9.3634e-04 - val_loss: 3.1616e-05
# Epoch 26/50
# 146/146 - 0s - 3ms/step - loss: 9.3541e-04 - val_loss: 3.1588e-05
# Epoch 27/50
# 146/146 - 1s - 5ms/step - loss: 9.3479e-04 - val_loss: 3.1580e-05
# Epoch 28/50
# 146/146 - 1s - 5ms/step - loss: 9.3447e-04 - val_loss: 3.1575e-05
# Epoch 29/50
# 146/146 - 0s - 3ms/step - loss: 9.3442e-04 - val_loss: 3.1558e-05
# Epoch 30/50
# 146/146 - 1s - 5ms/step - loss: 9.3459e-04 - val_loss: 3.1533e-05
# Epoch 31/50
# 146/146 - 1s - 4ms/step - loss: 9.3495e-04 - val_loss: 3.1511e-05
# Epoch 32/50
# 146/146 - 1s - 5ms/step - loss: 9.3547e-04 - val_loss: 3.1498e-05
# Epoch 33/50
# 146/146 - 0s - 3ms/step - loss: 9.3610e-04 - val_loss: 3.1493e-05
# Epoch 34/50
# 146/146 - 1s - 5ms/step - loss: 9.3681e-04 - val_loss: 3.1492e-05
# Epoch 35/50
# 146/146 - 0s - 3ms/step - loss: 9.3757e-04 - val_loss: 3.1492e-05
# Epoch 36/50
# 146/146 - 1s - 3ms/step - loss: 9.3835e-04 - val_loss: 3.1494e-05
# Epoch 37/50
# 146/146 - 0s - 3ms/step - loss: 9.3913e-04 - val_loss: 3.1496e-05
# Epoch 38/50
# 146/146 - 0s - 3ms/step - loss: 9.3988e-04 - val_loss: 3.1499e-05
# Epoch 39/50
# 146/146 - 0s - 3ms/step - loss: 9.4058e-04 - val_loss: 3.1501e-05
# Epoch 40/50
# 146/146 - 1s - 4ms/step - loss: 9.4122e-04 - val_loss: 3.1502e-05
# Epoch 41/50
# 146/146 - 0s - 3ms/step - loss: 9.4178e-04 - val_loss: 3.1502e-05
# Epoch 42/50
# 146/146 - 0s - 3ms/step - loss: 9.4226e-04 - val_loss: 3.1501e-05
# Epoch 43/50
# 146/146 - 0s - 3ms/step - loss: 9.4267e-04 - val_loss: 3.1499e-05
# Epoch 44/50
# 146/146 - 1s - 5ms/step - loss: 9.4301e-04 - val_loss: 3.1497e-05
# Epoch 45/50
# 146/146 - 0s - 3ms/step - loss: 9.4328e-04 - val_loss: 3.1494e-05
# Epoch 46/50
# 146/146 - 1s - 5ms/step - loss: 9.4349e-04 - val_loss: 3.1492e-05
# Epoch 47/50
# 146/146 - 1s - 5ms/step - loss: 9.4366e-04 - val_loss: 3.1489e-05
# Epoch 48/50
# 146/146 - 0s - 3ms/step - loss: 9.4379e-04 - val_loss: 3.1486e-05
# Epoch 49/50
# 146/146 - 1s - 5ms/step - loss: 9.4388e-04 - val_loss: 3.1484e-05
# Epoch 50/50
# 146/146 - 0s - 3ms/step - loss: 9.4395e-04 - val_loss: 3.1481e-05

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='train', linewidth = 2.5)
plt.plot(history.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
testPredict = model.predict(test_X)
print(testPredict.shape)
testPredict = testPredict.ravel()

print(testPredict.shape)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# (5077, 1)
# (5077,)

# %%
y_test_true = test[:,1]

# %%
import numpy as np

# %%
poll = np.array(df["so2"])

meanop = poll.mean()
stdop = poll.std()

y_test_true = y_test_true*stdop + meanop
testPredict = testPredict*stdop + meanop

# %%
rmse = np.sqrt(mean_squared_error(test_y, testPredict))
print("Test RMSE ="  ,rmse)
# Out:
# Test RMSE = 49.237194

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red", linewidth = 2.5)
plt.plot(testPredict, c = "green")
plt.title("Training data")
plt.show()

# %% [markdown]
# ### Model 2

# %%
model2 = Sequential()
model2.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model2.add(LSTM(256))
model2.add(Dense(64))
model2.add(Dropout(0.25))
model2.add(BatchNormalization())
model2.add(Dense(1))

model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 280,961 (1.07 MB)
#  Trainable params: 280,833 (1.07 MB)
#  Non-trainable params: 128 (512.00 B)

# %%
model2.compile(loss='mse', optimizer='adam')

hist2 = model2.fit(train_X, train_y, epochs=50, batch_size=128, validation_data=(test_X, test_y))
# Out:
# Epoch 1/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0085 - val_loss: 0.0034
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0013 - val_loss: 3.1712e-04
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0014 - val_loss: 1.8445e-04
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - val_loss: 4.6967e-04
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0014 - val_loss: 5.9728e-04
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 5.9142e-04
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0012 - val_loss: 5.8605e-04
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 7.6235e-04
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0011 - val_loss: 3.3429e-04
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - val_loss: 3.6561e-04
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 4.3274e-04
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0011 - val_loss: 1.8534e-04
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0011 - val_loss: 3.1420e-04
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - val_loss: 1.7633e-04
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0011 - val_loss: 1.7603e-04
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0012 - val_loss: 2.0319e-04
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - val_loss: 2.9388e-04
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0012 - val_loss: 1.9376e-04
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 2.1126e-04
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0010 - val_loss: 1.8084e-04
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - val_loss: 3.9260e-04
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 2.3141e-04
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0011 - val_loss: 4.2789e-04
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0011 - val_loss: 6.6151e-04
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 1.6891e-04
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - val_loss: 2.8042e-04
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0011 - val_loss: 1.8951e-04
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - val_loss: 1.7453e-04
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 5.0734e-04
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 4.9340e-04
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0011 - val_loss: 1.9319e-04
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - val_loss: 5.9778e-04
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0010 - val_loss: 4.4471e-04
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0011 - val_loss: 1.8595e-04
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 1.6993e-04
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0011 - val_loss: 2.2877e-04
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - val_loss: 8.0968e-04
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0011 - val_loss: 4.7691e-04
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - val_loss: 2.1238e-04
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - val_loss: 2.4568e-04
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0011 - val_loss: 6.2969e-04
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 1.9094e-04
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0011 - val_loss: 1.9760e-04
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 2.3006e-04
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0011 - val_loss: 1.7863e-04

# %%
plt.figure(figsize=(15,6))
plt.plot(hist2.history['loss'], label='train', linewidth = 2.5)
plt.plot(hist2.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
y_test_true = test[:,1]

# %%
testPredict2 = model2.predict(test_X)
testPredict2 = testPredict2.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["so2"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict2 = testPredict2*stdop + meanop
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 44.37105060928752 48.99930275463974

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict2))
print("Test(Validation) RMSE ="  ,rmse)
# Out:
# Test(Validation) RMSE = 0.6568064

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red", linewidth = 2.5)
plt.plot(testPredict2, c = "green")
plt.title("Training data")
plt.show()

# %% [markdown]
# ### Model 3

# %%
model3 = Sequential()
model3.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model3.add(LSTM(256))
model3.add(Dense(32))
model3.add(Dropout(0.25))
model3.add(BatchNormalization())
model3.add(Dense(1))
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           8,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 272,577 (1.04 MB)
#  Trainable params: 272,513 (1.04 MB)
#  Non-trainable params: 64 (256.00 B)

# %%
model3.compile(loss='mse', optimizer='adam')

hist3 = model3.fit(train_X, train_y, epochs=50, batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0187 - val_loss: 0.0116
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 0.0098
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 0.0091
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0075
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - val_loss: 0.0084
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 0.0074
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 0.0060
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0026 - val_loss: 0.0074
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0020 - val_loss: 0.0085
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0063
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 0.0038
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 0.0052
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0043
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 9.9579e-04
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 8.3977e-04
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 3.7691e-04
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 3.7713e-05
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 2.3044e-04
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 3.0706e-04
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 1.0679e-04
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 7.0729e-04
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 4.8720e-05
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 1.3606e-04
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0016 - val_loss: 4.5494e-05
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0014 - val_loss: 3.2989e-04
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 4.0385e-05
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015 - val_loss: 1.2279e-04
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0015 - val_loss: 4.2977e-04
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 8.7100e-04
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 1.4436e-04
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 6.3808e-05
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - val_loss: 1.1530e-04
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 5.2356e-05
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 1.4968e-04
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 1.6067e-04
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 3.7596e-05
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - val_loss: 9.1209e-05
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 2.4913e-04
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 6.1769e-05
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0014 - val_loss: 4.0434e-05
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 7.2287e-05
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 5.4252e-04
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 1.4723e-04
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 4.5067e-05
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 9.2730e-04

# %%
y_test_true = test[:,1]

# %%
testPredict3 = model3.predict(test_X)
testPredict3 = testPredict3.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["so2"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict3 = testPredict3*stdop + meanop
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 44.37105060928752 48.99930275463974

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict3))
print("Training RMSE ="  ,rmse)
# Out:
# Training RMSE = 1.4951853

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
# plt.xlim([1000,1250])
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red")
plt.plot(testPredict3, c = "darkblue")
plt.title("Training data")
plt.show()

# %% [markdown]
# ## Forecast

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[27.132513]
#  [27.208662]
#  [27.279833]
#  [27.346386]
#  [27.408646]
#  [27.466913]
#  [27.521463]]

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model2.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[27.009602]
#  [26.968103]
#  [26.926489]
#  [26.884745]
#  [26.842861]
#  [26.800823]
#  [26.758621]]

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model3.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[27.136915]
#  [27.216236]
#  [27.289446]
#  [27.356995]
#  [27.419304]
#  [27.476767]
#  [27.529747]]
