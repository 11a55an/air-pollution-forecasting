# %% [markdown]
# # LSTM - PM10

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/data_imputed.csv")

# %%
df['timestamp_local'] = pd.to_datetime(df['timestamp_local'])

# %%
df = df[['timestamp_local','temp','aqi','co','no2','o3','pm10','pm25','so2']]

# %%
df.head()
# Out:
#       timestamp_local  temp    aqi      co   no2    o3   pm10    pm25    so2
# 0 2022-02-01 00:00:00  12.6  385.0  1339.8  76.0  10.7  491.7  347.67  238.0
# 1 2022-02-01 01:00:00  11.5  404.0  1437.6  76.0   9.3  508.3  359.33  268.0
# 2 2022-02-01 02:00:00  11.9  421.0  1535.5  76.0   8.0  525.0  371.00  298.0
# 3 2022-02-01 03:00:00  12.2  425.0  1659.0  68.3   5.3  529.3  374.00  275.7
# 4 2022-02-01 04:00:00  11.9  430.0  1782.5  60.7   2.7  533.7  377.00  253.3

# %%
data = df[['pm10']]

# %% [markdown]
# ## Data PreProcessing

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
dataset = data
values = dataset.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
def series_to_supervised(data, n_in = 1, n_out = 1, dropnan = True):
    n_vars = 1 if type(data) is list else data.shape[1]
    
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
        
    return agg

# %%
# converting the dataset as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
print(reframed.shape)
# Out:
# (18217, 2)

# %%
reframed.head()
# Out:
#    var1(t-1)   var1(t)
# 1   0.704158  0.728373
# 2   0.728373  0.752735
# 3   0.752735  0.759008
# 4   0.759008  0.765427
# 5   0.765427  0.771699

# %%
reframed.columns
# Out:
# Index(['var1(t-1)', 'var1(t)'], dtype='object')

# %%
values = reframed.values

# We train the model on the 1st 3 years and then test on the last year (for now)
n_train_hours = int(365 * 24 * 1.5)

train = values[:n_train_hours, :]
test = values[n_train_hours:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D :- (no.of samples, no.of timesteps, no.of features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (13140, 1, 1) (13140,) (5077, 1, 1) (5077,)

# %%
train.shape, test.shape, values.shape
# Out:
# ((13140, 2), (5077, 2), (18217, 2))

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# ### Model 1

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(64))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_split=0.2, verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 146/146 - 4s - 28ms/step - loss: 0.0297 - val_loss: 0.0049
# Epoch 2/50
# 146/146 - 1s - 4ms/step - loss: 0.0123 - val_loss: 0.0032
# Epoch 3/50
# 146/146 - 1s - 5ms/step - loss: 0.0074 - val_loss: 0.0016
# Epoch 4/50
# 146/146 - 1s - 4ms/step - loss: 0.0036 - val_loss: 4.7012e-04
# Epoch 5/50
# 146/146 - 1s - 4ms/step - loss: 0.0016 - val_loss: 1.2558e-04
# Epoch 6/50
# 146/146 - 1s - 4ms/step - loss: 9.0627e-04 - val_loss: 7.7375e-05
# Epoch 7/50
# 146/146 - 1s - 5ms/step - loss: 7.8922e-04 - val_loss: 7.0616e-05
# Epoch 8/50
# 146/146 - 1s - 4ms/step - loss: 7.7901e-04 - val_loss: 6.9206e-05
# Epoch 9/50
# 146/146 - 1s - 4ms/step - loss: 7.7799e-04 - val_loss: 6.8827e-05
# Epoch 10/50
# 146/146 - 1s - 5ms/step - loss: 7.7708e-04 - val_loss: 6.8727e-05
# Epoch 11/50
# 146/146 - 1s - 4ms/step - loss: 7.7624e-04 - val_loss: 6.8727e-05
# Epoch 12/50
# 146/146 - 1s - 4ms/step - loss: 7.7548e-04 - val_loss: 6.8761e-05
# Epoch 13/50
# 146/146 - 1s - 4ms/step - loss: 7.7472e-04 - val_loss: 6.8763e-05
# Epoch 14/50
# 146/146 - 1s - 4ms/step - loss: 7.7388e-04 - val_loss: 6.8649e-05
# Epoch 15/50
# 146/146 - 1s - 4ms/step - loss: 7.7289e-04 - val_loss: 6.8354e-05
# Epoch 16/50
# 146/146 - 1s - 5ms/step - loss: 7.7170e-04 - val_loss: 6.7901e-05
# Epoch 17/50
# 146/146 - 1s - 4ms/step - loss: 7.7028e-04 - val_loss: 6.7440e-05
# Epoch 18/50
# 146/146 - 1s - 4ms/step - loss: 7.6866e-04 - val_loss: 6.7171e-05
# Epoch 19/50
# 146/146 - 1s - 4ms/step - loss: 7.6689e-04 - val_loss: 6.7197e-05
# Epoch 20/50
# 146/146 - 1s - 4ms/step - loss: 7.6503e-04 - val_loss: 6.7432e-05
# Epoch 21/50
# 146/146 - 1s - 4ms/step - loss: 7.6319e-04 - val_loss: 6.7645e-05
# Epoch 22/50
# 146/146 - 1s - 5ms/step - loss: 7.6142e-04 - val_loss: 6.7613e-05
# Epoch 23/50
# 146/146 - 1s - 4ms/step - loss: 7.5980e-04 - val_loss: 6.7257e-05
# Epoch 24/50
# 146/146 - 1s - 4ms/step - loss: 7.5835e-04 - val_loss: 6.6665e-05
# Epoch 25/50
# 146/146 - 1s - 5ms/step - loss: 7.5710e-04 - val_loss: 6.6015e-05
# Epoch 26/50
# 146/146 - 1s - 4ms/step - loss: 7.5601e-04 - val_loss: 6.5472e-05
# Epoch 27/50
# 146/146 - 1s - 4ms/step - loss: 7.5506e-04 - val_loss: 6.5148e-05
# Epoch 28/50
# 146/146 - 1s - 4ms/step - loss: 7.5422e-04 - val_loss: 6.5108e-05
# Epoch 29/50
# 146/146 - 1s - 4ms/step - loss: 7.5346e-04 - val_loss: 6.5393e-05
# Epoch 30/50
# 146/146 - 1s - 4ms/step - loss: 7.5277e-04 - val_loss: 6.5983e-05
# Epoch 31/50
# 146/146 - 1s - 5ms/step - loss: 7.5215e-04 - val_loss: 6.6739e-05
# Epoch 32/50
# 146/146 - 1s - 4ms/step - loss: 7.5161e-04 - val_loss: 6.7402e-05
# Epoch 33/50
# 146/146 - 1s - 4ms/step - loss: 7.5119e-04 - val_loss: 6.7710e-05
# Epoch 34/50
# 146/146 - 1s - 4ms/step - loss: 7.5092e-04 - val_loss: 6.7562e-05
# Epoch 35/50
# 146/146 - 1s - 4ms/step - loss: 7.5084e-04 - val_loss: 6.7050e-05
# Epoch 36/50
# 146/146 - 1s - 4ms/step - loss: 7.5092e-04 - val_loss: 6.6360e-05
# Epoch 37/50
# 146/146 - 1s - 5ms/step - loss: 7.5115e-04 - val_loss: 6.5668e-05
# Epoch 38/50
# 146/146 - 1s - 4ms/step - loss: 7.5145e-04 - val_loss: 6.5079e-05
# Epoch 39/50
# 146/146 - 1s - 4ms/step - loss: 7.5179e-04 - val_loss: 6.4630e-05
# Epoch 40/50
# 146/146 - 1s - 4ms/step - loss: 7.5213e-04 - val_loss: 6.4317e-05
# Epoch 41/50
# 146/146 - 1s - 4ms/step - loss: 7.5245e-04 - val_loss: 6.4114e-05
# Epoch 42/50
# 146/146 - 1s - 5ms/step - loss: 7.5274e-04 - val_loss: 6.3994e-05
# Epoch 43/50
# 146/146 - 1s - 4ms/step - loss: 7.5300e-04 - val_loss: 6.3932e-05
# Epoch 44/50
# 146/146 - 1s - 5ms/step - loss: 7.5324e-04 - val_loss: 6.3908e-05
# Epoch 45/50
# 146/146 - 1s - 4ms/step - loss: 7.5344e-04 - val_loss: 6.3906e-05
# Epoch 46/50
# 146/146 - 1s - 5ms/step - loss: 7.5363e-04 - val_loss: 6.3915e-05
# Epoch 47/50
# 146/146 - 1s - 6ms/step - loss: 7.5380e-04 - val_loss: 6.3929e-05
# Epoch 48/50
# 146/146 - 1s - 4ms/step - loss: 7.5394e-04 - val_loss: 6.3943e-05
# Epoch 49/50
# 146/146 - 1s - 5ms/step - loss: 7.5407e-04 - val_loss: 6.3955e-05
# Epoch 50/50
# 146/146 - 1s - 4ms/step - loss: 7.5418e-04 - val_loss: 6.3962e-05

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='train', linewidth = 2.5)
plt.plot(history.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
testPredict = model.predict(test_X)
print(testPredict.shape)
testPredict = testPredict.ravel()

print(testPredict.shape)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# (5077, 1)
# (5077,)

# %%
y_test_true = test[:,1]

# %%
import numpy as np

# %%
poll = np.array(df["pm10"])

meanop = poll.mean()
stdop = poll.std()

y_test_true = y_test_true*stdop + meanop
testPredict = testPredict*stdop + meanop

# %%
rmse = np.sqrt(mean_squared_error(test_y, testPredict))
print("Test RMSE ="  ,rmse)
# Out:
# Test RMSE = 132.8433

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red", linewidth = 2.5)
plt.plot(testPredict, c = "green")
plt.title("Training data")
plt.show()

# %% [markdown]
# ### Model 2

# %%
model2 = Sequential()
model2.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model2.add(LSTM(256))
model2.add(Dense(64))
model2.add(Dropout(0.25))
model2.add(BatchNormalization())
model2.add(Dense(1))

model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 280,961 (1.07 MB)
#  Trainable params: 280,833 (1.07 MB)
#  Non-trainable params: 128 (512.00 B)

# %%
model2.compile(loss='mse', optimizer='adam')

hist2 = model2.fit(train_X, train_y, epochs=50, batch_size=128, validation_data=(test_X, test_y))
# Out:
# Epoch 1/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0147 - val_loss: 0.0070
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0011 - val_loss: 0.0067
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0011 - val_loss: 0.0056
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0012 - val_loss: 0.0039
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0012 - val_loss: 7.3928e-04
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0011 - val_loss: 4.5140e-04
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0011 - val_loss: 4.2942e-04
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0013 - val_loss: 7.2892e-04
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0011 - val_loss: 1.8832e-04
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0012 - val_loss: 7.3564e-04
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0011 - val_loss: 3.3031e-04
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0011 - val_loss: 2.5908e-04
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0010 - val_loss: 2.6959e-04
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0011 - val_loss: 2.0274e-04
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 9.9910e-04 - val_loss: 2.6985e-04
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0011 - val_loss: 4.1674e-04
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 9.3383e-04 - val_loss: 1.9087e-04
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 9.6242e-04 - val_loss: 2.0148e-04
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0010 - val_loss: 1.8637e-04
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0010 - val_loss: 5.3573e-04
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0010 - val_loss: 4.8903e-04
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 9.7304e-04 - val_loss: 2.8981e-04
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0010 - val_loss: 4.6780e-04
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 9.8858e-04 - val_loss: 4.2886e-04
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0010 - val_loss: 5.5908e-04
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 9.4326e-04 - val_loss: 1.8503e-04
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.3919e-04 - val_loss: 2.7006e-04
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 9.0971e-04 - val_loss: 1.9189e-04
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 9.9660e-04 - val_loss: 2.1600e-04
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 9.0203e-04 - val_loss: 2.3482e-04
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0010 - val_loss: 2.2022e-04
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0010 - val_loss: 3.6995e-04
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 9.6614e-04 - val_loss: 2.3474e-04
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 9.8097e-04 - val_loss: 3.0550e-04
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 9.6830e-04 - val_loss: 3.5494e-04
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0010 - val_loss: 2.3956e-04
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 9.8066e-04 - val_loss: 2.3733e-04
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 9.0423e-04 - val_loss: 2.1821e-04
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 9.1707e-04 - val_loss: 1.9609e-04
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 8.7634e-04 - val_loss: 2.0264e-04
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0010 - val_loss: 2.1067e-04
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 9.4035e-04 - val_loss: 2.0548e-04
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 9.6829e-04 - val_loss: 2.8755e-04
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 9.9404e-04 - val_loss: 3.7221e-04
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0010 - val_loss: 4.2994e-04
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 9.3942e-04 - val_loss: 2.1501e-04
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 8.6533e-04 - val_loss: 2.7865e-04
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 9.4651e-04 - val_loss: 2.0843e-04

# %%
plt.figure(figsize=(15,6))
plt.plot(hist2.history['loss'], label='train', linewidth = 2.5)
plt.plot(hist2.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
y_test_true = test[:,1]

# %%
testPredict2 = model2.predict(test_X)
testPredict2 = testPredict2.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pm10"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict2 = testPredict2*stdop + meanop
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 120.48709518059061 88.95670648289507

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict2))
print("Test(Validation) RMSE ="  ,rmse)
# Out:
# Test(Validation) RMSE = 1.2876309

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red", linewidth = 2.5)
plt.plot(testPredict2, c = "green")
plt.title("Training data")
plt.show()

# %% [markdown]
# ### Model 3

# %%
model3 = Sequential()
model3.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model3.add(LSTM(256))
model3.add(Dense(32))
model3.add(Dropout(0.25))
model3.add(BatchNormalization())
model3.add(Dense(1))
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           8,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 272,577 (1.04 MB)
#  Trainable params: 272,513 (1.04 MB)
#  Non-trainable params: 64 (256.00 B)

# %%
model3.compile(loss='mse', optimizer='adam')

hist3 = model3.fit(train_X, train_y, epochs=50, batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0335 - val_loss: 0.0169
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0015 - val_loss: 0.0142
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - val_loss: 0.0129
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013 - val_loss: 0.0134
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0014 - val_loss: 0.0133
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0014 - val_loss: 0.0127
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0013 - val_loss: 0.0109
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0014 - val_loss: 0.0128
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0015 - val_loss: 0.0114
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013 - val_loss: 0.0094
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 0.0089
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0013 - val_loss: 0.0048
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0014 - val_loss: 0.0057
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0015 - val_loss: 0.0033
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0013 - val_loss: 9.4108e-04
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0013 - val_loss: 6.9092e-05
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0015 - val_loss: 7.5310e-05
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0012 - val_loss: 3.6282e-04
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0017 - val_loss: 8.3437e-04
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0014 - val_loss: 6.9424e-04
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 3.3311e-04
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0013 - val_loss: 9.2808e-05
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012 - val_loss: 1.0202e-04
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0012 - val_loss: 3.0605e-04
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0015 - val_loss: 4.1293e-04
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 6.9800e-05
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013 - val_loss: 7.0315e-05
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0014 - val_loss: 8.5839e-04
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0012 - val_loss: 1.2797e-04
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0012 - val_loss: 7.1796e-04
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0012 - val_loss: 8.9872e-05
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0012 - val_loss: 9.2994e-05
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0014 - val_loss: 1.1840e-04
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 8.5861e-05
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0012 - val_loss: 5.9395e-04
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0012 - val_loss: 2.2686e-04
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0011 - val_loss: 7.4214e-04
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011 - val_loss: 6.4094e-04
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0014 - val_loss: 3.2040e-04
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0012 - val_loss: 2.2032e-04
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 7.0576e-04
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0012 - val_loss: 0.0013

# %%
y_test_true = test[:,1]

# %%
testPredict3 = model3.predict(test_X)
testPredict3 = testPredict3.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pm25"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict3 = testPredict3*stdop + meanop
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 82.54162147326821 65.27856687407635

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict3))
print("Training RMSE ="  ,rmse)
# Out:
# Training RMSE = 2.6133194

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
# plt.xlim([1000,1250])
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red")
plt.plot(testPredict3, c = "darkblue")
plt.title("Training data")
plt.show()

# %% [markdown]
# ## Forecast

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[27.132513]
#  [27.208662]
#  [27.279833]
#  [27.346386]
#  [27.408646]
#  [27.466913]
#  [27.521463]]

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model2.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[27.009602]
#  [26.968103]
#  [26.926489]
#  [26.884745]
#  [26.842861]
#  [26.800823]
#  [26.758621]]

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model3.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[27.136915]
#  [27.216236]
#  [27.289446]
#  [27.356995]
#  [27.419304]
#  [27.476767]
#  [27.529747]]
