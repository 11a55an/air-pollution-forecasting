# %% [markdown]
# # LSTM - PM2.5

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/data_imputed.csv")

# %%
df['timestamp_local'] = pd.to_datetime(df['timestamp_local'])

# %%
df = df[['timestamp_local','temp','aqi','co','no2','o3','pm10','pm25','so2']]

# %%
df.head()
# Out:
#       timestamp_local  temp    aqi      co   no2    o3   pm10    pm25    so2
# 0 2022-02-01 00:00:00  12.6  385.0  1339.8  76.0  10.7  491.7  347.67  238.0
# 1 2022-02-01 01:00:00  11.5  404.0  1437.6  76.0   9.3  508.3  359.33  268.0
# 2 2022-02-01 02:00:00  11.9  421.0  1535.5  76.0   8.0  525.0  371.00  298.0
# 3 2022-02-01 03:00:00  12.2  425.0  1659.0  68.3   5.3  529.3  374.00  275.7
# 4 2022-02-01 04:00:00  11.9  430.0  1782.5  60.7   2.7  533.7  377.00  253.3

# %%
data = df[['pm25']]

# %% [markdown]
# ## Data PreProcessing

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
dataset = data
values = dataset.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
def series_to_supervised(data, n_in = 1, n_out = 1, dropnan = True):
    n_vars = 1 if type(data) is list else data.shape[1]
    
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
        
    return agg

# %%
# converting the dataset as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
print(reframed.shape)
# Out:
# (18217, 2)

# %%
reframed.head()
# Out:
#    var1(t-1)   var1(t)
# 1   0.579534  0.599311
# 2   0.599311  0.619106
# 3   0.619106  0.624194
# 4   0.624194  0.629283
# 5   0.629283  0.634371

# %%
reframed.columns
# Out:
# Index(['var1(t-1)', 'var1(t)'], dtype='object')

# %%
values = reframed.values

# We train the model on the 1st 3 years and then test on the last year (for now)
n_train_hours = int(365 * 24 * 1.5)

train = values[:n_train_hours, :]
test = values[n_train_hours:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D :- (no.of samples, no.of timesteps, no.of features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (13140, 1, 1) (13140,) (5077, 1, 1) (5077,)

# %%
train.shape, test.shape, values.shape
# Out:
# ((13140, 2), (5077, 2), (18217, 2))

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# ### Model 1

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(64))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_split=0.2, verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 146/146 - 3s - 22ms/step - loss: 0.0210 - val_loss: 0.0036
# Epoch 2/50
# 146/146 - 1s - 6ms/step - loss: 0.0093 - val_loss: 0.0023
# Epoch 3/50
# 146/146 - 0s - 3ms/step - loss: 0.0056 - val_loss: 9.9215e-04
# Epoch 4/50
# 146/146 - 1s - 5ms/step - loss: 0.0026 - val_loss: 2.1332e-04
# Epoch 5/50
# 146/146 - 1s - 5ms/step - loss: 0.0011 - val_loss: 5.1244e-05
# Epoch 6/50
# 146/146 - 1s - 4ms/step - loss: 6.3498e-04 - val_loss: 3.8012e-05
# Epoch 7/50
# 146/146 - 1s - 6ms/step - loss: 5.4763e-04 - val_loss: 3.6259e-05
# Epoch 8/50
# 146/146 - 0s - 3ms/step - loss: 5.3825e-04 - val_loss: 3.5866e-05
# Epoch 9/50
# 146/146 - 0s - 3ms/step - loss: 5.3709e-04 - val_loss: 3.5759e-05
# Epoch 10/50
# 146/146 - 0s - 3ms/step - loss: 5.3669e-04 - val_loss: 3.5760e-05
# Epoch 11/50
# 146/146 - 1s - 5ms/step - loss: 5.3638e-04 - val_loss: 3.5803e-05
# Epoch 12/50
# 146/146 - 0s - 3ms/step - loss: 5.3604e-04 - val_loss: 3.5824e-05
# Epoch 13/50
# 146/146 - 0s - 3ms/step - loss: 5.3560e-04 - val_loss: 3.5759e-05
# Epoch 14/50
# 146/146 - 0s - 3ms/step - loss: 5.3503e-04 - val_loss: 3.5598e-05
# Epoch 15/50
# 146/146 - 0s - 3ms/step - loss: 5.3430e-04 - val_loss: 3.5432e-05
# Epoch 16/50
# 146/146 - 1s - 5ms/step - loss: 5.3344e-04 - val_loss: 3.5409e-05
# Epoch 17/50
# 146/146 - 1s - 5ms/step - loss: 5.3248e-04 - val_loss: 3.5620e-05
# Epoch 18/50
# 146/146 - 0s - 3ms/step - loss: 5.3148e-04 - val_loss: 3.5997e-05
# Epoch 19/50
# 146/146 - 0s - 3ms/step - loss: 5.3049e-04 - val_loss: 3.6348e-05
# Epoch 20/50
# 146/146 - 0s - 3ms/step - loss: 5.2957e-04 - val_loss: 3.6481e-05
# Epoch 21/50
# 146/146 - 0s - 3ms/step - loss: 5.2876e-04 - val_loss: 3.6318e-05
# Epoch 22/50
# 146/146 - 1s - 5ms/step - loss: 5.2805e-04 - val_loss: 3.5921e-05
# Epoch 23/50
# 146/146 - 1s - 5ms/step - loss: 5.2746e-04 - val_loss: 3.5428e-05
# Epoch 24/50
# 146/146 - 0s - 3ms/step - loss: 5.2697e-04 - val_loss: 3.4982e-05
# Epoch 25/50
# 146/146 - 1s - 5ms/step - loss: 5.2653e-04 - val_loss: 3.4692e-05
# Epoch 26/50
# 146/146 - 0s - 3ms/step - loss: 5.2614e-04 - val_loss: 3.4641e-05
# Epoch 27/50
# 146/146 - 0s - 3ms/step - loss: 5.2578e-04 - val_loss: 3.4888e-05
# Epoch 28/50
# 146/146 - 1s - 5ms/step - loss: 5.2542e-04 - val_loss: 3.5410e-05
# Epoch 29/50
# 146/146 - 0s - 3ms/step - loss: 5.2505e-04 - val_loss: 3.6047e-05
# Epoch 30/50
# 146/146 - 0s - 3ms/step - loss: 5.2465e-04 - val_loss: 3.6531e-05
# Epoch 31/50
# 146/146 - 0s - 3ms/step - loss: 5.2425e-04 - val_loss: 3.6637e-05
# Epoch 32/50
# 146/146 - 0s - 3ms/step - loss: 5.2389e-04 - val_loss: 3.6332e-05
# Epoch 33/50
# 146/146 - 1s - 5ms/step - loss: 5.2360e-04 - val_loss: 3.5760e-05
# Epoch 34/50
# 146/146 - 1s - 5ms/step - loss: 5.2342e-04 - val_loss: 3.5130e-05
# Epoch 35/50
# 146/146 - 1s - 4ms/step - loss: 5.2332e-04 - val_loss: 3.4607e-05
# Epoch 36/50
# 146/146 - 0s - 3ms/step - loss: 5.2328e-04 - val_loss: 3.4271e-05
# Epoch 37/50
# 146/146 - 1s - 5ms/step - loss: 5.2326e-04 - val_loss: 3.4135e-05
# Epoch 38/50
# 146/146 - 1s - 5ms/step - loss: 5.2325e-04 - val_loss: 3.4177e-05
# Epoch 39/50
# 146/146 - 0s - 3ms/step - loss: 5.2323e-04 - val_loss: 3.4355e-05
# Epoch 40/50
# 146/146 - 1s - 5ms/step - loss: 5.2322e-04 - val_loss: 3.4619e-05
# Epoch 41/50
# 146/146 - 0s - 3ms/step - loss: 5.2321e-04 - val_loss: 3.4910e-05
# Epoch 42/50
# 146/146 - 0s - 3ms/step - loss: 5.2323e-04 - val_loss: 3.5178e-05
# Epoch 43/50
# 146/146 - 0s - 3ms/step - loss: 5.2327e-04 - val_loss: 3.5388e-05
# Epoch 44/50
# 146/146 - 1s - 5ms/step - loss: 5.2333e-04 - val_loss: 3.5527e-05
# Epoch 45/50
# 146/146 - 0s - 3ms/step - loss: 5.2340e-04 - val_loss: 3.5602e-05
# Epoch 46/50
# 146/146 - 0s - 3ms/step - loss: 5.2348e-04 - val_loss: 3.5627e-05
# Epoch 47/50
# 146/146 - 0s - 3ms/step - loss: 5.2356e-04 - val_loss: 3.5619e-05
# Epoch 48/50
# 146/146 - 0s - 3ms/step - loss: 5.2363e-04 - val_loss: 3.5592e-05
# Epoch 49/50
# 146/146 - 0s - 3ms/step - loss: 5.2370e-04 - val_loss: 3.5559e-05
# Epoch 50/50
# 146/146 - 1s - 5ms/step - loss: 5.2377e-04 - val_loss: 3.5526e-05

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='train', linewidth = 2.5)
plt.plot(history.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
testPredict = model.predict(test_X)
print(testPredict.shape)
testPredict = testPredict.ravel()

print(testPredict.shape)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# (5077, 1)
# (5077,)

# %%
y_test_true = test[:,1]

# %%
import numpy as np

# %%
poll = np.array(df["pm25"])

meanop = poll.mean()
stdop = poll.std()

y_test_true = y_test_true*stdop + meanop
testPredict = testPredict*stdop + meanop

# %%
rmse = np.sqrt(mean_squared_error(test_y, testPredict))
print("Test RMSE ="  ,rmse)
# Out:
# Test RMSE = 89.32621

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red", linewidth = 2.5)
plt.plot(testPredict, c = "green")
plt.title("Training data")
plt.show()

# %% [markdown]
# ### Model 2

# %%
model2 = Sequential()
model2.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model2.add(LSTM(256))
model2.add(Dense(64))
model2.add(Dropout(0.25))
model2.add(BatchNormalization())
model2.add(Dense(1))

model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 280,961 (1.07 MB)
#  Trainable params: 280,833 (1.07 MB)
#  Non-trainable params: 128 (512.00 B)

# %%
model2.compile(loss='mse', optimizer='adam')

hist2 = model2.fit(train_X, train_y, epochs=50, batch_size=128, validation_data=(test_X, test_y))
# Out:
# Epoch 1/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0073 - val_loss: 0.0053
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.3233e-04 - val_loss: 0.0043
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0010 - val_loss: 0.0029
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.2353e-04 - val_loss: 0.0018
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 8.7995e-04 - val_loss: 0.0014
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 9.5641e-04 - val_loss: 4.4539e-04
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.9870e-04 - val_loss: 3.7440e-04
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 7.8599e-04 - val_loss: 1.3043e-04
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.6582e-04 - val_loss: 1.1007e-04
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.9341e-04 - val_loss: 1.4741e-04
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.3506e-04 - val_loss: 1.9024e-04
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.5015e-04 - val_loss: 3.4018e-04
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 7.5592e-04 - val_loss: 1.9763e-04
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.6088e-04 - val_loss: 2.1941e-04
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.1811e-04 - val_loss: 1.1265e-04
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 7.9753e-04 - val_loss: 6.5926e-04
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.6649e-04 - val_loss: 1.6625e-04
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 6.8310e-04 - val_loss: 6.1704e-04
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 6.7474e-04 - val_loss: 1.2152e-04
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 6.8227e-04 - val_loss: 1.7140e-04
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.9662e-04 - val_loss: 1.9874e-04
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 6.8144e-04 - val_loss: 2.8728e-04
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.9300e-04 - val_loss: 2.3390e-04
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.9419e-04 - val_loss: 1.3674e-04
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 6.3645e-04 - val_loss: 2.2272e-04
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 6.5653e-04 - val_loss: 1.2709e-04
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 6.7454e-04 - val_loss: 3.6662e-04
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 7.2255e-04 - val_loss: 1.9527e-04
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.6615e-04 - val_loss: 1.6572e-04
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 6.2606e-04 - val_loss: 1.1177e-04
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 6.6483e-04 - val_loss: 3.7387e-04
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.7368e-04 - val_loss: 1.4178e-04
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 6.0661e-04 - val_loss: 1.2166e-04
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 6.9155e-04 - val_loss: 1.8494e-04
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 7.2674e-04 - val_loss: 4.7663e-04
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.5272e-04 - val_loss: 3.0238e-04
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 6.8012e-04 - val_loss: 2.3177e-04
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.3759e-04 - val_loss: 1.9255e-04
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.5930e-04 - val_loss: 1.2859e-04
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.4133e-04 - val_loss: 1.4709e-04
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 6.2441e-04 - val_loss: 1.2554e-04
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 6.4639e-04 - val_loss: 3.6952e-04
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 6.1275e-04 - val_loss: 1.3024e-04
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.4628e-04 - val_loss: 1.1696e-04
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 7.0705e-04 - val_loss: 3.4267e-04
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 6.5359e-04 - val_loss: 3.3631e-04
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 7.3108e-04 - val_loss: 2.2255e-04
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 6.4157e-04 - val_loss: 1.2881e-04
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.8588e-04 - val_loss: 2.0947e-04

# %%
plt.figure(figsize=(15,6))
plt.plot(hist2.history['loss'], label='train', linewidth = 2.5)
plt.plot(hist2.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
y_test_true = test[:,1]

# %%
testPredict2 = model2.predict(test_X)
testPredict2 = testPredict2.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pm25"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict2 = testPredict2*stdop + meanop
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 82.54162147326821 65.27856687407635

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict2))
print("Test(Validation) RMSE ="  ,rmse)
# Out:
# Test(Validation) RMSE = 0.9454441

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red", linewidth = 2.5)
plt.plot(testPredict2, c = "green")
plt.title("Training data")
plt.show()

# %% [markdown]
# ### Model 3

# %%
model3 = Sequential()
model3.add(Input(shape=(train_X.shape[1], train_X.shape[2])))
model3.add(LSTM(256))
model3.add(Dense(32))
model3.add(Dropout(0.25))
model3.add(BatchNormalization())
model3.add(Dense(1))
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           8,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 272,577 (1.04 MB)
#  Trainable params: 272,513 (1.04 MB)
#  Non-trainable params: 64 (256.00 B)

# %%
model3.compile(loss='mse', optimizer='adam')

hist3 = model3.fit(train_X, train_y, epochs=50, batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - loss: 0.0204 - val_loss: 0.0142
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 0.0105
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0010 - val_loss: 0.0101
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 8.9210e-04 - val_loss: 0.0103
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0010 - val_loss: 0.0097
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.7713e-04 - val_loss: 0.0092
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011 - val_loss: 0.0083
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.4346e-04 - val_loss: 0.0074
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.4480e-04 - val_loss: 0.0066
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.5185e-04 - val_loss: 0.0086
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011 - val_loss: 0.0068
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.7754e-04 - val_loss: 0.0049
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.0842e-04 - val_loss: 0.0057
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0010 - val_loss: 4.4916e-04
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.2578e-04 - val_loss: 1.8309e-04
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0011 - val_loss: 1.8344e-04
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0011 - val_loss: 9.6341e-04
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0012 - val_loss: 3.3902e-05
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.9962e-04 - val_loss: 0.0017
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.1106e-04 - val_loss: 1.4459e-04
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.5685e-04 - val_loss: 2.1251e-04
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.0035e-04 - val_loss: 1.3727e-04
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.8700e-04 - val_loss: 0.0014
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0011 - val_loss: 2.0261e-04
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.2317e-04 - val_loss: 1.7177e-04
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.1399e-04 - val_loss: 3.4327e-04
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.2482e-04 - val_loss: 2.9080e-04
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.2252e-04 - val_loss: 6.7499e-05
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.4971e-04 - val_loss: 3.7111e-04
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.9276e-04 - val_loss: 0.0018
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0011 - val_loss: 1.7935e-04
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.5944e-04 - val_loss: 8.7261e-04
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0010 - val_loss: 4.7113e-05
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.4288e-04 - val_loss: 3.3602e-05
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.6873e-04 - val_loss: 3.5282e-05
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.6209e-04 - val_loss: 3.4070e-05
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.3651e-04 - val_loss: 2.1569e-04
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.8181e-04 - val_loss: 4.8277e-05
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.3126e-04 - val_loss: 5.7740e-05
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.9489e-04 - val_loss: 7.0972e-04
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.6750e-04 - val_loss: 4.0910e-04
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.3081e-04 - val_loss: 4.1108e-04
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.6973e-04 - val_loss: 0.0020
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.7324e-04 - val_loss: 4.7955e-05
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.5919e-04 - val_loss: 9.1722e-04
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.7221e-04 - val_loss: 6.7076e-05
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0012 - val_loss: 0.0011

# %%
y_test_true = test[:,1]

# %%
testPredict3 = model3.predict(test_X)
testPredict3 = testPredict3.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pm25"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict3 = testPredict3*stdop + meanop
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 82.54162147326821 65.27856687407635

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict3))
print("Training RMSE ="  ,rmse)
# Out:
# Training RMSE = 2.3876832

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
# plt.xlim([1000,1250])
plt.ylabel("degrees")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "red")
plt.plot(testPredict3, c = "darkblue")
plt.title("Training data")
plt.show()

# %% [markdown]
# ## Forecast

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[27.132513]
#  [27.208662]
#  [27.279833]
#  [27.346386]
#  [27.408646]
#  [27.466913]
#  [27.521463]]

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model2.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[27.009602]
#  [26.968103]
#  [26.926489]
#  [26.884745]
#  [26.842861]
#  [26.800823]
#  [26.758621]]

# %%
# Assuming you have `model` already trained and `meanop` and `stdop` calculated

# Initialize an array to store forecasted values
forecast_values = []

# Use the last available data point from your dataset as the initial input
last_input = test_X[-1]

# Define the number of time steps you want to forecast
num_steps = 7  # Adjust according to your needs

for _ in range(num_steps):
    # Reshape input data for prediction
    input_data = np.expand_dims(last_input, axis=0)

    # Make prediction
    forecast = model3.predict(input_data)

    # Inverse transform forecasted value
    forecast = forecast.ravel() * stdop + meanop

    # Store forecasted value
    forecast_values.append(forecast)

    # Update input data for the next time step by shifting and appending forecasted value
    last_input = np.roll(last_input, -1)
    last_input[-1] = (forecast - meanop) / stdop  # Normalize the forecasted value

# Convert forecast_values to a numpy array
forecast_values = np.array(forecast_values)

# Print or use forecast_values for further analysis
print(forecast_values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[27.136915]
#  [27.216236]
#  [27.289446]
#  [27.356995]
#  [27.419304]
#  [27.476767]
#  [27.529747]]
